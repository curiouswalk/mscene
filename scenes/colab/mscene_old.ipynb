# %% [markdown]
# <a href="https://colab.research.google.com/github/curiouswalk/mscene/blob/main/scenes/colab/mscene.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [CuriousWalk](https://www.curiouswalk.com)
#
# ## Mscene
#
# Animate in Python With Manim<br>&emsp;[mscene.curiouswalk.com](https://mscene.curiouswalk.com)
#
#
# Manim is an animation engine designed to program precise animations for science videos.
#
# > The Manim Community Developers. *Manim — Mathematical Animation Framework* [Computer software].<br>[www.manim.community](https://www.manim.community)
#
# [Manim in Colab]&ensp;[mscene.curiouswalk.com/colab](https://mscene.curiouswalk.com/colab)

# %% [markdown]
# ## Setup
#
# [Installation Guide](https://docs.manim.community/en/stable/installation.html)
#
# Download `mscene.py` from [mscene.curiouswalk.com/src/mscene.py](https://mscene.curiouswalk.com/src/mscene.py) and complete this setup process to get started.

# %%
# download mscene.py; print working directory; list contents
# !wget -nv mscene.curiouswalk.com/src/mscene.py; pwd; ls

# %%
from google.colab import files
# open mscene.py
files.view("mscene.py")

# %% [markdown]
# Install, import, and configure Manim with `mscene.py` script.
#
# **Commands**
#
# >`%run mscene install` — install Manim<br>
# `%run mscene -l install` — install Manim without LaTeX<br>
# `%run mscene setup` — import and configure Manim<br>
# `%run mscene -h` — view commands

# %%
# install Manim without LaTeX
# %run mscene -l install

# %%
# import and configure Manim
# %run mscene setup

# %% [markdown]
# ## Manim Scene
#
# [Manim CLI](https://docs.manim.community/en/stable/guides/configuration.html)
#
# **`%%manim -ql NewScene`** is a magic command.
#
# > `%%manim` runs code cells with manim in a subprocess.<br>
# `-ql` renders in 480p at 15fps.<br>
# &emsp;&emsp;`-qm` — 720p, 30fps<br>
# &emsp;&emsp;`-qh` — 1080p, 60fps<br>
# &emsp;&emsp;`-qp` — 1440p, 60fps<br>
# &emsp;&emsp;`-qk` — 2160p, 60fps<br>
# `NewScene` is the scene class to be rendered.
#
# [Example Gallery](https://docs.manim.community/en/stable/examples.html)

# %%
# %%manim -qm ExampleScene
#
# class ExampleScene(Scene):
#     def construct(self):
#         banner = ManimBanner()
#         self.play(banner.create())
#         self.play(banner.expand())
#         self.wait(1.5)

# %% [markdown]
# ## New Scene

# %%
# %%manim -ql NewScene
#
# class NewScene(Scene):
#     def construct(self):

# %% [markdown]
# ## End Session
#
# Run this code cell to disconnect the runtime and terminate the session.

# %%
from google.colab import runtime
runtime.unassign()
