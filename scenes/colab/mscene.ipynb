# %% [markdown]
# <a href="https://colab.research.google.com/github/curiouswalk/mscene/blob/main/scenes/colab/mscene.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mscene
#
# A Python library for creating science animations with Manim in Google Colab. &#10024;&nbsp;[mscene.curiouswalk.com](https://mscene.curiouswalk.com)
#
# Review the [documentation](https://mscene.curiouswalk.com/docs) before getting started.

# %% [markdown]
# ## Setup

# %%
# %pip install -q mscene
import mscene
# view commands
# %mscene -h

# %%
# %mscene -l manim

# %%
from mscene.manim import *

# %% [markdown]
# ## Example Scene

# %%
# %%manim -qm ExampleScene
#
# class ExampleScene(Scene):
#     def construct(self):
#         banner = ManimBanner()
#         self.play(banner.create())
#         self.play(banner.expand())
#         self.wait(1.5)

# %% [markdown]
# ## New Scene

# %%
# %%manim -ql NewScene
#
# class NewScene(Scene):
#     def construct(self):

# %% [markdown]
# ## End Session
#
# Run this code cell to disconnect the runtime and terminate the session.

# %%
from google.colab import runtime
runtime.unassign()
